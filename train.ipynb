# %% [markdown]
# SETUP

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install git+https://github.com/huggingface/transformers
# !pip install git+https://github.com/huggingface/accelerate
# Out:
# ...
#   Cloning https://github.com/huggingface/transformers to /tmp/pip-req-build-myxrhbh_
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers /tmp/pip-req-build-myxrhbh_
#   Resolved https://github.com/huggingface/transformers to commit 74f5e4a1fad5a578e5ecb3b47fe48dc98ba21ff2
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for transformers: filename=transformers-4.53.0.dev0-py3-none-any.whl size=11462183 sha256=8c695afdf571533c793818558944547415e1675e3e0e8e1d9a664d4101ba8e9a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-7l12d9lc/wheels/04/a3/f1/b88775f8e1665827525b19ac7590250f1038d947067beba9fb
# Successfully built transformers
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.52.4
#     Uninstalling transformers-4.52.4:
#       Successfully uninstalled transformers-4.52.4
# ...

# %%
# !pip install --upgrade datasets
# !pip install seqeval
# !pip install evaluate
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 30.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 19.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
#   Attempting uninstall: datasets
#     Found existing installation: datasets 2.14.4
#     Uninstalling datasets-2.14.4:
#       Successfully uninstalled datasets-2.14.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 4.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !accelerate config
# !accelerate test
# Out:
# --------------------------------------------------------------------------------In which compute environment are you running?
# Please input a choice index (starting from 0), and press enter
#  ➔  This machine
#     AWS (Amazon SageMaker)
#
# This machine
# --------------------------------------------------------------------------------Which type of machine are you using?
# Please input a choice index (starting from 0), and press enter
#  ➔  No distributed training
#     multi-CPU
#     multi-XPU
#     multi-HPU
#     multi-GPU
#     multi-NPU
#     multi-MLU
#     multi-SDAA
#     multi-MUSA
#     TPU
#
# No distributed training
# Do you want to run your training on CPU only (even if a GPU / Apple Silicon / Ascend NPU device is available)? [yes/NO]:
# Do you wish to optimize your script with torch dynamo?[yes/NO]:
# Do you want to use DeepSpeed? [yes/NO]:
# What GPU(s) (by id) should be used for training on this machine as a comma-separated list? [all]:
# ...

# %% [markdown]
# ESPERIMENTI CON LEARNING RATE

# %%
#LR1

# %cd '/content/drive/MyDrive/NER'
# %env TASK_NAME=ner

# !accelerate launch project_run_ner_no_trainer.py \
  --model_name_or_path dbmdz/bert-base-italian-cased \
  --dataset_name babelscape/wikineural \
  --trust_remote_code \
  --task_name ner \
  --with_tracking \
  --max_length 128 \
  --per_device_train_batch_size 32 \
  --learning_rate 2e-5 \
  --num_train_epochs 3 \
  --seed 42\
  --output_dir /tmp/ner/
# Out:
# /content/drive/.shortcut-targets-by-id/1hM6fbeKlhUDLcXrq9gg12vT5gB5B4mjU/NER
# env: TASK_NAME=ner
# ipex flag is deprecated, will be removed in Accelerate v1.10. From 2.7.0, PyTorch has all needed optimizations for Intel CPU and XPU.
# 2025-06-21 15:48:40.713270: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750520920.732826   31332 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750520920.738659   31332 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !cp /tmp/ner/* /content/drive/MyDrive/NER/lr1/
# Out:
# cp: -r not specified; omitting directory '/tmp/ner/ner_no_trainer'

# %%
# LR2

# %cd '/content/drive/MyDrive/NER'
# %env TASK_NAME=ner

# !accelerate launch project_run_ner_no_trainer.py \
  --model_name_or_path dbmdz/bert-base-italian-cased \
  --dataset_name babelscape/wikineural \
  --trust_remote_code \
  --task_name ner \
  --max_length 128 \
  --per_device_train_batch_size 32 \
  --learning_rate 0.01 \
  --num_train_epochs 3 \
  --output_dir /tmp/ner/
# Out:
# /content/drive/.shortcut-targets-by-id/1hM6fbeKlhUDLcXrq9gg12vT5gB5B4mjU/NER
# env: TASK_NAME=ner
# ipex flag is deprecated, will be removed in Accelerate v1.10. From 2.7.0, PyTorch has all needed optimizations for Intel CPU and XPU.
# 2025-06-21 13:55:44.020287: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750514144.318273    2857 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750514144.397732    2857 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
#LR3

# %cd '/content/drive/MyDrive/NER'
# %env TASK_NAME=ner

# !accelerate launch project_run_ner_no_trainer.py \
  --model_name_or_path dbmdz/bert-base-italian-cased \
  --dataset_name babelscape/wikineural \
  --trust_remote_code \
  --task_name ner \
  --with_tracking \
  --max_length 128 \
  --per_device_train_batch_size 32 \
  --learning_rate 1e-5 \
  --num_train_epochs 3 \
  --seed 42\
  --output_dir /tmp/ner/
# Out:
# /content/drive/.shortcut-targets-by-id/1hM6fbeKlhUDLcXrq9gg12vT5gB5B4mjU/NER
# env: TASK_NAME=ner
# ipex flag is deprecated, will be removed in Accelerate v1.10. From 2.7.0, PyTorch has all needed optimizations for Intel CPU and XPU.
# 2025-06-21 16:16:17.130295: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750522577.154788   38298 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750522577.161876   38298 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !cp /tmp/ner/* /content/drive/MyDrive/NER/lr3/
# Out:
# cp: -r not specified; omitting directory '/tmp/ner/ner_no_trainer'

# %%
#LR4

# %cd '/content/drive/MyDrive/NER'
# %env TASK_NAME=ner

# !accelerate launch project_run_ner_no_trainer.py \
  --model_name_or_path dbmdz/bert-base-italian-cased \
  --dataset_name babelscape/wikineural \
  --trust_remote_code \
  --task_name ner \
  --with_tracking \
  --max_length 128 \
  --per_device_train_batch_size 32 \
  --learning_rate 3e-5 \
  --num_train_epochs 3 \
  --seed 42\
  --output_dir /tmp/ner/
# Out:
# /content/drive/.shortcut-targets-by-id/1hM6fbeKlhUDLcXrq9gg12vT5gB5B4mjU/NER
# env: TASK_NAME=ner
# ipex flag is deprecated, will be removed in Accelerate v1.10. From 2.7.0, PyTorch has all needed optimizations for Intel CPU and XPU.
# 2025-06-22 08:22:05.103717: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750580525.363416    2268 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750580525.433269    2268 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !cp /tmp/ner/* /content/drive/MyDrive/NER/lr4/
# Out:
# cp: -r not specified; omitting directory '/tmp/ner/ner_no_trainer'

# %%
#LR5

# %cd '/content/drive/MyDrive/NER'
# %env TASK_NAME=ner

# !accelerate launch project_run_ner_no_trainer.py \
  --model_name_or_path dbmdz/bert-base-italian-cased \
  --dataset_name babelscape/wikineural \
  --trust_remote_code \
  --task_name ner \
  --with_tracking \
  --max_length 128 \
  --per_device_train_batch_size 32 \
  --learning_rate 5e-5 \
  --num_train_epochs 3 \
  --seed 42\
  --output_dir /tmp/ner/
# Out:
# /content/drive/.shortcut-targets-by-id/1hM6fbeKlhUDLcXrq9gg12vT5gB5B4mjU/NER
# env: TASK_NAME=ner
# ipex flag is deprecated, will be removed in Accelerate v1.10. From 2.7.0, PyTorch has all needed optimizations for Intel CPU and XPU.
# 2025-06-22 08:48:35.989946: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750582116.009402    8974 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750582116.015358    8974 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !cp /tmp/ner/* /content/drive/MyDrive/NER/lr5/
# Out:
# cp: -r not specified; omitting directory '/tmp/ner/ner_no_trainer'

# %%
#LR6

# %cd '/content/drive/MyDrive/NER'
# %env TASK_NAME=ner

# !accelerate launch project_run_ner_no_trainer.py \
  --model_name_or_path dbmdz/bert-base-italian-cased \
  --dataset_name babelscape/wikineural \
  --trust_remote_code \
  --task_name ner \
  --with_tracking \
  --max_length 128 \
  --per_device_train_batch_size 32 \
  --learning_rate 4e-5 \
  --num_train_epochs 3 \
  --seed 42\
  --output_dir /tmp/ner/
# Out:
# /content/drive/.shortcut-targets-by-id/1hM6fbeKlhUDLcXrq9gg12vT5gB5B4mjU/NER
# env: TASK_NAME=ner
# ipex flag is deprecated, will be removed in Accelerate v1.10. From 2.7.0, PyTorch has all needed optimizations for Intel CPU and XPU.
# 2025-06-22 09:53:05.104700: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750585985.397088    2901 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750585985.501934    2901 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !cp /tmp/ner/* /content/drive/MyDrive/NER/lr6/

# %% [markdown]
# ESPERIMENTI CON BATCH SIZE E LR 4e-5

# %%
#BS 1 ---> 16
# %cd '/content/drive/MyDrive/NER'
# %env TASK_NAME=ner

# !accelerate launch project_run_ner_no_trainer.py \
  --model_name_or_path dbmdz/bert-base-italian-cased \
  --dataset_name babelscape/wikineural \
  --trust_remote_code \
  --task_name ner \
  --with_tracking \
  --max_length 128 \
  --per_device_train_batch_size 16 \
  --learning_rate 4e-5 \
  --num_train_epochs 3 \
  --seed 42\
  --output_dir /tmp/ner/
# Out:
# /content/drive/.shortcut-targets-by-id/1hM6fbeKlhUDLcXrq9gg12vT5gB5B4mjU/NER
# env: TASK_NAME=ner
# ipex flag is deprecated, will be removed in Accelerate v1.10. From 2.7.0, PyTorch has all needed optimizations for Intel CPU and XPU.
# 2025-06-22 19:39:17.376010: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750621157.636480    4406 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750621157.706280    4406 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !cp -r /tmp/ner/* /content/drive/MyDrive/NER/bs2_1/

# %%
#BS 3 ---> 64
# %cd '/content/drive/MyDrive/NER'
# %env TASK_NAME=ner

# !accelerate launch project_run_ner_no_trainer.py \
  --model_name_or_path dbmdz/bert-base-italian-cased \
  --dataset_name babelscape/wikineural \
  --trust_remote_code \
  --task_name ner \
  --with_tracking \
  --max_length 128 \
  --per_device_train_batch_size 64 \
  --learning_rate 4e-5 \
  --num_train_epochs 3 \
  --seed 42\
  --output_dir /tmp/ner/
# Out:
# /content/drive/.shortcut-targets-by-id/1hM6fbeKlhUDLcXrq9gg12vT5gB5B4mjU/NER
# env: TASK_NAME=ner
# ipex flag is deprecated, will be removed in Accelerate v1.10. From 2.7.0, PyTorch has all needed optimizations for Intel CPU and XPU.
# 2025-06-22 20:13:15.467332: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750623195.486754   12966 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750623195.492896   12966 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !cp -r /tmp/ner/* /content/drive/MyDrive/NER/bs2_3/

# %%
#BS 3 ---> 128
# %cd '/content/drive/MyDrive/NER'
# %env TASK_NAME=ner

# !accelerate launch project_run_ner_no_trainer.py \
  --model_name_or_path dbmdz/bert-base-italian-cased \
  --dataset_name babelscape/wikineural \
  --trust_remote_code \
  --task_name ner \
  --with_tracking \
  --max_length 128 \
  --per_device_train_batch_size 128 \
  --learning_rate 4e-5 \
  --num_train_epochs 3 \
  --seed 42\
  --output_dir /tmp/ner/
# Out:
# /content/drive/.shortcut-targets-by-id/1hM6fbeKlhUDLcXrq9gg12vT5gB5B4mjU/NER
# env: TASK_NAME=ner
# ipex flag is deprecated, will be removed in Accelerate v1.10. From 2.7.0, PyTorch has all needed optimizations for Intel CPU and XPU.
# 2025-06-22 20:37:43.224074: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750624663.243866   19283 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750624663.250186   19283 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !cp -r /tmp/ner/* /content/drive/MyDrive/NER/bs2_4/

# %% [markdown]
# ESPERIMENTI CON EPOCHE (Batch size = 16, learning rate = 4e-5)

# %%
#EP2 ---> 2
# %cd '/content/drive/MyDrive/NER'
# %env TASK_NAME=ner

# !accelerate launch project_run_ner_no_trainer.py \
  --model_name_or_path dbmdz/bert-base-italian-cased \
  --dataset_name babelscape/wikineural \
  --trust_remote_code \
  --task_name ner \
  --with_tracking \
  --max_length 128 \
  --per_device_train_batch_size 16 \
  --learning_rate 4e-5 \
  --num_train_epochs 2 \
  --seed 42\
  --output_dir /tmp/ner/
# Out:
# /content/drive/MyDrive/NER
# env: TASK_NAME=ner
# ipex flag is deprecated, will be removed in Accelerate v1.10. From 2.7.0, PyTorch has all needed optimizations for Intel CPU and XPU.
# 2025-06-23 10:01:58.400059: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750672918.419739   16428 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750672918.425885   16428 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !cp -r /tmp/ner/* /content/drive/MyDrive/NER/ep2/

# %%
#EP3 ---> 5
# %cd '/content/drive/MyDrive/NER'
# %env TASK_NAME=ner

# !accelerate launch project_run_ner_no_trainer.py \
  --model_name_or_path dbmdz/bert-base-italian-cased \
  --dataset_name babelscape/wikineural \
  --trust_remote_code \
  --task_name ner \
  --with_tracking \
  --max_length 128 \
  --per_device_train_batch_size 16 \
  --learning_rate 4e-5 \
  --num_train_epochs 5 \
  --seed 42\
  --output_dir /tmp/ner/
# Out:
# /content/drive/.shortcut-targets-by-id/1hM6fbeKlhUDLcXrq9gg12vT5gB5B4mjU/NER
# env: TASK_NAME=ner
# ipex flag is deprecated, will be removed in Accelerate v1.10. From 2.7.0, PyTorch has all needed optimizations for Intel CPU and XPU.
# 2025-06-23 12:00:14.946429: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750680014.966378   16809 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750680014.972403   16809 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !cp -r /tmp/ner/* /content/drive/MyDrive/NER/ep3/

# %%
#EP4 ---> 10
# %cd '/content/drive/MyDrive/NER'
# %env TASK_NAME=ner

# !accelerate launch project_run_ner_no_trainer.py \
  --model_name_or_path dbmdz/bert-base-italian-cased \
  --dataset_name babelscape/wikineural \
  --trust_remote_code \
  --task_name ner \
  --with_tracking \
  --max_length 128 \
  --per_device_train_batch_size 16 \
  --learning_rate 4e-5 \
  --num_train_epochs 10 \
  --seed 42\
  --output_dir /tmp/ner/
# Out:
# /content/drive/.shortcut-targets-by-id/1hM6fbeKlhUDLcXrq9gg12vT5gB5B4mjU/NER
# env: TASK_NAME=ner
# ipex flag is deprecated, will be removed in Accelerate v1.10. From 2.7.0, PyTorch has all needed optimizations for Intel CPU and XPU.
# 2025-06-23 13:35:35.019981: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750685735.039455   40389 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750685735.045443   40389 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
